# %%
# %load_ext autoreload
# %autoreload 2

import sys; 
sys.path.insert(0, '../../esinet')
sys.path.insert(0, '../')

import numpy as np
from copy import deepcopy
from scipy.sparse.csgraph import laplacian
from matplotlib import pyplot as plt
from scipy.spatial.distance import cdist
from scipy.stats import pearsonr
import mne
from esinet import Simulation
from esinet.forward import get_info, create_forward_model
from esinet.util import unpack_fwd
from scipy.sparse.csgraph import laplacian

pp = dict(surface='white', hemi='both')

# %%
info = get_info(kind='biosemi64')
fwd = create_forward_model(info=info, sampling='ico3')

leadfield, pos = unpack_fwd(fwd)[1:3]
n_chans, n_dipoles = leadfield.shape
dist = cdist(pos, pos)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    1.8s remaining:    1.8s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished

# %%
# settings = dict(number_of_sources=1, extents=40, duration_of_trial=0.01, target_snr=99999999999)
settings = dict(number_of_sources=4, extents=(1, 40), duration_of_trial=1, target_snr=99999)

sim = Simulation(fwd, info, settings).simulate(2)
stc = sim.source_data[0]
evoked = sim.eeg_data[0].average()
y = evoked.data
x = stc.data

brain = stc.plot(**pp)
brain.add_text(0.1, 0.9, 'Ground Truth', 'title',
               font_size=14)
# Out:
# Simulating data based on sparse patches.
# 100%|██████████| 2/2 [00:00<00:00, 17.14it/s]
# 100%|██████████| 2/2 [00:00<00:00, 401.12it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.40it/s]
# Using pyvistaqt 3d backend.
#
# Using control points [6.54233146e-09 1.47370072e-08 8.08125532e-08]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`

# %% [markdown]
# # Algo

# %% [markdown]
# ## Helpers

# %%
def generator(fwd, batch_size=1284, n_sources=2, n_orders=2, verbose=0):

    # Parameters
    # batch_size = 1111
    # n_sources=5
    # n_orders=2
    # verbose=0

    amplitude_range = (0.001,1)
    adjacency = mne.spatial_src_adjacency(fwd["src"], verbose=verbose).toarray()
    gradient = abs(laplacian(adjacency))
    leadfield = fwd["sol"]["data"]
    leadfield -= leadfield.mean()

    leadfield_norm = deepcopy(leadfield)
    leadfield_norm /= np.linalg.norm(leadfield_norm, axis=0)

    n_chans, n_dipoles = leadfield.shape

    sources = np.identity(n_dipoles)
    for _ in range(n_orders-1):
        new_sources = sources[-n_dipoles:, -n_dipoles:] @ gradient
        new_sources /= new_sources.max(axis=0)
        sources = np.concatenate( [sources, new_sources], axis=0 )



    n_candidates = sources.shape[0]

    while True:
        print("ye")
        # select sources and their amplitudes
        n_sources_batch = np.random.randint(1, n_sources+1, batch_size)
        selection = [np.random.randint(0, n_candidates, n) for n in n_sources_batch]
        amplitudes = [np.random.uniform(*amplitude_range, n) * np.random.choice([1,-1], n) for n in n_sources_batch]
        # print(amplitudes[0], type(amplitudes[0]), sources[selection[0]].shape)
        y = np.stack([(amplitudes[i] @ sources[selection[i]]) / len(amplitudes[i]) for i in range(batch_size)], axis=0)
        y = (y.T / abs(y).max(axis=1)).T
        x = leadfield @ y.T
        # scale x
        x -= x.mean(axis=0)
        x /= np.linalg.norm(x, axis=0)
        
        # OMP
        # x = leadfield_norm.T @ x
        # x /= np.linalg.norm(x, axis=0)

        y = y[:, np.newaxis, :]
        x = x.T[:, np.newaxis, :]
        # y = (y!=0).astype(float)
        
        yield (x, y)

# %%
gen = generator(fwd, batch_size=5, n_sources=n_sources)
x_test, y_test = gen.__next__()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Lukas\Documents\projects\invert\dev\new_ann.ipynb Zelle 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lukas/Documents/projects/invert/dev/new_ann.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> gen = generator(fwd, batch_size=5, n_sources=n_sources)
#       <a href='vscode-notebook-cell:/c%3A/Users/Lukas/Documents/projects/invert/dev/new_ann.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> x_test, y_test = gen.__next__()
#
# NameError: name 'n_sources' is not defined

# %%
x = np.array([100, 0.01, -0.01, -100])
x<0

# %%
# out = Lambda(lambda x: K.sign(x) * tf.keras.backend.clip(x, K.max(K.abs(x))*eps, None    ))
# out = Lambda(lambda x: x * tf.cast(abs(x) > K.max(K.abs(x))*eps, tf.float32))
# out = Lambda(lambda x: K.sign(x) * tf.keras.layers.ThresholdedReLU(theta=K.max(K.abs(x))*eps)(K.abs(x)))
out = Lambda(lambda x: x * tf.cast(K.greater(K.abs(x), K.max(K.abs(x))*eps), tf.float32))
# K.switch(K.less(K.abs(x), 0.1), 0*x  , x)
out(x)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, TimeDistributed, Lambda, Activation
from tensorflow.keras import backend as K
tf.keras.backend.set_image_data_format('channels_last')

# L1 = lambda x: K.mean(K.abs(x))
# LR = lambda x: K.mean(K.abs(x)) / K.mean(K.square(x))
# LR = lambda x: K.mean(K.square(x)) / K.mean(K.abs(x))

n_channels = evoked.data.shape[0]
n_dipoles = x.shape[0]

n_dense_units = 300
activation_function = "relu"
batch_size = 1284
n_sources = 5
n_orders = 2
epochs = 100
n_hl = 1
eps = 0.1

inputs = tf.keras.Input(shape=(None, n_channels), name='Input')

fc1 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC1'))(inputs)

for n in range(n_hl):
    fc1 = TimeDistributed(Dense(n_dense_units, 
                activation=activation_function,
                name='FC'+str(n+2)))(fc1)

out = TimeDistributed(Dense(n_dipoles, 
            activation="linear", 
            name='Output'))(fc1)

# out = Lambda(lambda x: K.sign(x) * tf.keras.backend.clip(K.abs(x), K.max(K.abs(x))*eps, None    ))(out)
# out = Lambda(lambda x: K.sign(x) * tf.keras.layers.ThresholdedReLU(theta=K.max(K.abs(x))*eps)(K.abs(x)))(out)
out = Lambda(lambda x: x * tf.cast(K.greater(K.abs(x), K.max(K.abs(x))*eps), tf.float32))(out)
# out = Lambda(lambda x: K.sign(x) * Activation(tf.keras.layers.ThresholdedReLU(theta=K.max(K.abs(x))*eps))(K.abs(x)))(out)

# out = TimeDistributed(Dense(n_dipoles, 
#             activation="linear", 
#             name='Output'))(out)
# out = Lambda(lambda x: K.sign(x) * tf.keras.backend.clip(K.abs(x), K.max(K.abs(x))*eps, None    ))(out)
# out = Lambda(lambda x: K.sign(x) * tf.keras.layers.ThresholdedReLU(theta=K.max(K.abs(x))*eps)(K.abs(x)))(out)
# out = Lambda(lambda x: x * tf.cast(K.greater(K.abs(x), K.max(K.abs(x))*eps), tf.float32))(out)
# out = Lambda(lambda x: K.sign(x) * Activation(tf.keras.layers.ThresholdedReLU(theta=K.max(K.abs(x))*eps))(K.abs(x)))(out)



model = tf.keras.Model(inputs=inputs, outputs=out, name='AutoANN')
# model.add_loss(LR(out)*1e-2)

model.compile(loss="cosine_similarity", optimizer="adam")
# model.compile(loss="huber", optimizer="adam")

model.summary()

model.fit(x=generator(fwd, batch_size=batch_size, n_sources=n_sources, n_orders=n_orders), epochs=epochs,  steps_per_epoch=20)
# Out:
# Model: "AutoANN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, None, 64)]        0
#
#  time_distributed (TimeDistr  (None, None, 300)        19500
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, None, 300)        90300
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, None, 1284)       386484
#  tributed)
#
#  lambda (Lambda)             (None, None, 1284)        0
#
# =================================================================
# Total params: 496,284
# Trainable params: 496,284
# Non-trainable params: 0
# _________________________________________________________________
# ye
# Epoch 1/100
# ye
#  1/20 [>.............................] - ETA: 17s - loss: -0.0018ye
# ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.0047 ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.0066ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.0086ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.0104ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.0122ye
#  8/20 [===========>..................] - ETA: 0s - loss: -0.0143ye
#  9/20 [============>.................] - ETA: 0s - loss: -0.0162ye
# 10/20 [==============>...............] - ETA: 0s - loss: -0.0182ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.0199ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.0217ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.0235ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.0253ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.0271ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.0289ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.0306ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.0322ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.0339ye
# 20/20 [==============================] - 3s 92ms/step - loss: -0.0354
# Epoch 2/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.0687ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.0700ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.0715ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.0728ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.0739ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.0746ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.0757ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.0767ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.0776ye
# 10/20 [==============>...............] - ETA: 0s - loss: -0.0784ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.0794ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.0804ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.0814ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.0823ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.0833ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.0842ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.0852ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.0862ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.0870ye
# 20/20 [==============================] - 2s 90ms/step - loss: -0.0878
# Epoch 3/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.1046ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.1057ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.1076ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.1084ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.1092ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.1098ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.1105ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.1114ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.1124ye
# 10/20 [==============>...............] - ETA: 0s - loss: -0.1131ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.1137ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.1145ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.1151ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.1162ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.1169ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.1175ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.1181ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.1187ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.1193ye
# 20/20 [==============================] - 2s 89ms/step - loss: -0.1200
# Epoch 4/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.1342ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.1350ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.1363ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.1359ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.1367ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.1373ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.1376ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.1384ye
#  9/20 [============>.................] - ETA: 0s - loss: -0.1391ye
# 10/20 [==============>...............] - ETA: 0s - loss: -0.1399ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.1404ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.1410ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.1419ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.1423ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.1432ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.1436ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.1442ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.1445ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.1449ye
# 20/20 [==============================] - 2s 89ms/step - loss: -0.1455
# Epoch 5/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.1574ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.1575ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.1600ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.1597ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.1601ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.1603ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.1600ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.1602ye
#  9/20 [============>.................] - ETA: 0s - loss: -0.1607ye
# 10/20 [==============>...............] - ETA: 0s - loss: -0.1608ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.1614ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.1617ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.1623ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.1632ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.1633ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.1636ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.1640ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.1643ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.1647ye
# 20/20 [==============================] - 2s 89ms/step - loss: -0.1648
# Epoch 6/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.1781ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.1793ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.1778ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.1785ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.1784ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.1783ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.1801ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.1800ye
#  9/20 [============>.................] - ETA: 0s - loss: -0.1809ye
# 10/20 [==============>...............] - ETA: 0s - loss: -0.1812ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.1810ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.1817ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.1816ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.1822ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.1827ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.1831ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.1832ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.1836ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.1845ye
# 20/20 [==============================] - 2s 88ms/step - loss: -0.1848
# Epoch 7/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.1911ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.1938ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.1937ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.1936ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.1932ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.1936ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.1944ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.1955ye
#  9/20 [============>.................] - ETA: 0s - loss: -0.1954ye
# 10/20 [==============>...............] - ETA: 0s - loss: -0.1960ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.1972ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.1965ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.1968ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.1974ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.1972ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.1974ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.1977ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.1989ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.1990ye
# 20/20 [==============================] - 2s 90ms/step - loss: -0.1994
# Epoch 8/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.2014ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.2043ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.2061ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.2072ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.2061ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.2062ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.2057ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.2057ye
#  9/20 [============>.................] - ETA: 0s - loss: -0.2069ye
# 10/20 [==============>...............] - ETA: 0s - loss: -0.2083ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.2082ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.2089ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.2100ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.2114ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.2118ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.2120ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.2125ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.2129ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.2127ye
# 20/20 [==============================] - 2s 90ms/step - loss: -0.2132
# Epoch 9/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.
ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.3607ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3620ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3625ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3626ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3622ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3596ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3606ye
# 20/20 [==============================] - 3s 130ms/step - loss: -0.3609
# Epoch 33/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.3426ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.3531ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.3607ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.3626ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.3592ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.3627ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.3653ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.3668ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3679ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3630ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.3620ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.3626ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.3620ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3621ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3620ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3602ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3603ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3611ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3627ye
# 20/20 [==============================] - 2s 104ms/step - loss: -0.3634
# Epoch 34/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.3407ye
#  2/20 [==>...........................] - ETA: 2s - loss: -0.3501ye
#  3/20 [===>..........................] - ETA: 1s - loss: -0.3481ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.3528ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.3590ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.3621ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.3616ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.3596ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3593ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3603ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.3616ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.3634ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.3596ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3601ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3612ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3617ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3613ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3619ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3625ye
# 20/20 [==============================] - 2s 106ms/step - loss: -0.3631
# Epoch 35/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.3751ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.3624ye
#  3/20 [===>..........................] - ETA: 9s - loss: -0.3611ye
#  4/20 [=====>........................] - ETA: 6s - loss: -0.3620ye
#  5/20 [======>.......................] - ETA: 6s - loss: -0.3634ye
#  6/20 [========>.....................] - ETA: 7s - loss: -0.3617ye
#  7/20 [=========>....................] - ETA: 6s - loss: -0.3623ye
#  8/20 [===========>..................] - ETA: 5s - loss: -0.3651ye
# ...
#  3/20 [===>..........................] - ETA: 3s - loss: -0.3693ye
#  4/20 [=====>........................] - ETA: 2s - loss: -0.3757ye
#  5/20 [======>.......................] - ETA: 2s - loss: -0.3744ye
#  6/20 [========>.....................] - ETA: 2s - loss: -0.3748ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.3767ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.3777ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3780ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3752ye
# 11/20 [===============>..............] - ETA: 1s - loss: -0.3726ye
# 12/20 [=================>............] - ETA: 1s - loss: -0.3731ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.3732ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3736ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3729ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3732ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3724ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3732ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3737ye
# 20/20 [==============================] - 3s 144ms/step - loss: -0.3739
# Epoch 37/100
# ye
#  1/20 [>.............................] - ETA: 2s - loss: -0.3696ye
#  2/20 [==>...........................] - ETA: 4s - loss: -0.3784ye
#  3/20 [===>..........................] - ETA: 3s - loss: -0.3764ye
#  4/20 [=====>........................] - ETA: 3s - loss: -0.3735ye
#  5/20 [======>.......................] - ETA: 2s - loss: -0.3744ye
#  6/20 [========>.....................] - ETA: 2s - loss: -0.3757ye
#  7/20 [=========>....................] - ETA: 2s - loss: -0.3734ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.3725ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3739ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3741ye
# 11/20 [===============>..............] - ETA: 1s - loss: -0.3752ye
# 12/20 [=================>............] - ETA: 1s - loss: -0.3750ye
# 13/20 [==================>...........] - ETA: 1s - loss: -0.3756ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3765ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3756ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3754ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3751ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3750ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3753ye
# 20/20 [==============================] - 3s 171ms/step - loss: -0.3752
# Epoch 38/100
# ye
#  1/20 [>.............................] - ETA: 2s - loss: -0.3601ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.3626ye
#  3/20 [===>..........................] - ETA: 2s - loss: -0.3688ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.3709ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.3658ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.3687ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.3709ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.3660ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3656ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3670ye
# 11/20 [===============>..............] - ETA: 1s - loss: -0.3690ye
# 12/20 [=================>............] - ETA: 1s - loss: -0.3697ye
# 13/20 [==================>...........] - ETA: 1s - loss: -0.3697ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3701ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3712ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3722ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3721ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3718ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3708ye
# 20/20 [==============================] - 3s 158ms/step - loss: -0.3714
# Epoch 39/100
# ye
#  1/20 [>.............................] - ETA: 1s - loss: -0.3863ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.3833ye
#  3/20 [===>..........................] - ETA: 2s - loss: -0.3686ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.3734ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.3662ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.3680ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.3720ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.3720ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3737ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3752ye
# 11/20 [===============>..............] - ETA: 0s - loss: -0.3766ye
# 12/20 [=================>............] - ETA: 0s - loss: -0.3784ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.3781ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3773ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3776ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3786ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3783ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3774ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3777ye
# 20/20 [==============================] - 2s 121ms/step - loss: -0.3772
# Epoch 40/100
# ye
#  1/20 [>.............................] - ETA: 3s - loss: -0.3988ye
#  2/20 [==>...........................] - ETA: 1s - loss: -0.3842ye
#  3/20 [===>..........................] - ETA: 2s - loss: -0.3884ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.3780ye
#  5/20 [======>.......................] - ETA: 1s - loss: -0.3779ye
#  6/20 [========>.....................] - ETA: 1s - loss: -0.3788ye
#  7/20 [=========>....................] - ETA: 1s - loss: -0.3818ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.3809ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3816ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3818ye
# 11/20 [===============>..............] - ETA: 1s - loss: -0.3832ye
# 12/20 [=================>............] - ETA: 1s - loss: -0.3833ye
# 13/20 [==================>...........] - ETA: 0s - loss: -0.3840ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3839ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3840ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3845ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3840ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3832ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3823ye
# 20/20 [==============================] - 3s 149ms/step - loss: -0.3825
# Epoch 41/100
# ye
#  1/20 [>.............................] - ETA: 6s - loss: -0.3647ye
#  2/20 [==>...........................] - ETA: 2s - loss: -0.3675ye
#  3/20 [===>..........................] - ETA: 2s - loss: -0.3724ye
#  4/20 [=====>........................] - ETA: 2s - loss: -0.3774ye
#  5/20 [======>.......................] - ETA: 2s - loss: -0.3791ye
#  6/20 [========>.....................] - ETA: 2s - loss: -0.3778ye
#  7/20 [=========>....................] - ETA: 2s - loss: -0.3790ye
#  8/20 [===========>..................] - ETA: 2s - loss: -0.3790ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3792ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3753ye
# 11/20 [===============>..............] - ETA: 1s - loss: -0.3745ye
# 12/20 [=================>............] - ETA: 1s - loss: -0.3746ye
# 13/20 [==================>...........] - ETA: 1s - loss: -0.3750ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3749ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3756ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3768ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3769ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3754ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3756ye
# 20/20 [==============================] - 4s 183ms/step - loss: -0.3748
# Epoch 42/100
# ye
#  1/20 [>.............................] - ETA: 3s - loss: -0.3809ye
#  2/20 [==>...........................] - ETA: 2s - loss: -0.3859ye
#  3/20 [===>..........................] - ETA: 2s - loss: -0.3813ye
#  4/20 [=====>........................] - ETA: 1s - loss: -0.3839ye
#  5/20 [======>.......................] - ETA: 2s - loss: -0.3834ye
#  6/20 [========>.....................] - ETA: 2s - loss: -0.3814ye
#  7/20 [=========>....................] - ETA: 2s - loss: -0.3840ye
#  8/20 [===========>..................] - ETA: 1s - loss: -0.3817ye
#  9/20 [============>.................] - ETA: 1s - loss: -0.3808ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3791ye
# 11/20 [===============>..............] - ETA: 1s - loss: -0.3791ye
# 12/20 [=================>............] - ETA: 1s - loss: -0.3801ye
# 13/20 [==================>...........] - ETA: 1s - loss: -0.3797ye
# 14/20 [====================>.........] - ETA: 0s - loss: -0.3794ye
# 15/20 [=====================>........] - ETA: 0s - loss: -0.3807ye
# 16/20 [=======================>......] - ETA: 0s - loss: -0.3797ye
# 17/20 [========================>.....] - ETA: 0s - loss: -0.3795ye
# 18/20 [==========================>...] - ETA: 0s - loss: -0.3799ye
# 19/20 [===========================>..] - ETA: 0s - loss: -0.3808ye
# 20/20 [==============================] - 3s 137ms/step - loss: -0.3811
# Epoch 43/100
# ye
#  1/20 [>.............................] - ETA: 2s - loss: -0.3464ye
#  2/20 [==>...........................] - ETA: 3s - loss: -0.3666ye
#  3/20 [===>..........................] - ETA: 3s - loss: -0.3748ye
#  4/20 [=====>........................] - ETA: 3s - loss: -0.3759ye
#  5/20 [======>.......................] - ETA: 3s - loss: -0.3812ye
#  6/20 [========>.....................] - ETA: 3s - loss: -0.3802ye
#  7/20 [=========>....................] - ETA: 2s - loss: -0.3788ye
#  8/20 [===========>..................] - ETA: 2s - loss: -0.3782ye
#  9/20 [============>.................] - ETA: 2s - loss: -0.3754ye
# 10/20 [==============>...............] - ETA: 1s - loss: -0.3772ye
# 11/20 [===============>..............] - ETA: 1s - loss: -0.3782ye
# 12/20 [=================>............] - ETA: 1s - loss: -0.3783ye
# 13/20 [==================>...........] - ETA: 1s - loss: -0.3781ye
# 14/20 [====================>.........] - ETA: 1s - loss: -0.3786ye
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Lukas\Documents\projects\invert\dev\new_ann.ipynb Zelle 11 in <cell line: 60>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Lukas/Documents/projects/invert/dev/new_ann.ipynb#W6sZmlsZQ%3D%3D?line=55'>56</a> # model.compile(loss="huber", optimizer="adam")
#      <a href='vscode-notebook-cell:/c%3A/Users/Lukas/Documents/projects/invert/dev/new_ann.ipynb#W6sZmlsZQ%3D%3D?line=57'>58</a> model.summary()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Lukas/Documents/projects/invert/dev/new_ann.ipynb#W6sZmlsZQ%3D%3D?line=59'>60</a> model.fit(x=generator(fwd, batch_size=batch_size, n_sources=n_sources, n_orders=n_orders), epochs=epochs,  steps_per_epoch=20)
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\Lukas\Envs\invertenv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
gen = generator(fwd, batch_size=5, n_sources=n_sources, n_orders=n_orders)
x_test, y_test = gen.__next__()

y_hat = model.predict(x_test)

stc_ = stc.copy()
stc_.data = y_test[:, 0].T
stc_.plot(**pp, brain_kwargs=dict(title="Ground Truths"))

stc_ = stc.copy()
stc_.data = y_hat[:, 0].T
stc_.plot(**pp, brain_kwargs=dict(title="Preds"))
# Out:
# ye
# 1/1 [==============================] - 0s 91ms/step
# Using control points [0. 0. 1.]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`
# Using control points [0.02136925 0.02453144 0.05638586]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`
# Using control points [0.01494075 0.01618905 0.02966308]
# Using control points [0.01494075 0.01618905 0.02966308]

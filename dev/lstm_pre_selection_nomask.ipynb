# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib qt
import sys; sys.path.insert(0, '../')
from copy import deepcopy
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import pearsonr
import mne
from esinet import Simulation
from esinet.forward import get_info, create_forward_model
from esinet.util import unpack_fwd
pp = dict(surface='white', hemi='both', verbose=0)

# %% [markdown]
# # Funs

# %%
def prep_data(sim):
    X = np.stack([eeg.average().data for eeg in sim.eeg_data])
    y = np.stack([src.data for src in sim.source_data])
    for i, (x_sample, y_sample) in enumerate(zip(X, y)):
        # X[i] = np.stack([(x - np.mean(x)) / np.std(x) for x in x_sample.T], axis=0).T
        # y[i] = np.stack([ y / np.max(abs(y)) for y in y_sample.T], axis=0).T

        X[i] = np.stack([x - np.mean(x) for x in x_sample.T], axis=0).T
        X[i] = np.stack([x / np.std(x) for x in x_sample.T], axis=0).T
        
        # X[i] /= np.linalg.norm(X[i])
        y[i] /= np.max(abs(y[i]))

    X = np.swapaxes(X, 1,2)
    y = np.swapaxes(y, 1,2)
    
    return X, y
    
def make_mask(y, thresh=0.001):
    y_mask = np.zeros((y.shape[0], y.shape[-1]))
    for i, y_samp in enumerate(y):
        yy = abs(y_samp).mean(axis=0)
        

        y_mask[i] = (yy > yy.max()*thresh).astype(int)
    return y_mask

def get_components(X, leadfield_norm):
    for i, x_sample in enumerate(X):
        X[i] = np.stack([x - np.mean(x) for x in x_sample.T], axis=0).T
        X[i] /= np.linalg.norm(X[i])

    X_components = np.stack([leadfield_norm.T @ X_sample.T for X_sample in X], axis=0)
    X_components = np.swapaxes(X_components, 1, 2)
    X_components = np.stack([XX / np.linalg.norm(XX) for XX in X_components], axis=0)
    return np.abs(X_components)

# %% [markdown]
# # Forward

# %%
info = get_info(kind='biosemi128')
fwd = create_forward_model(info=info, sampling='ico3')

leadfield, pos = unpack_fwd(fwd)[1:3]
leadfield -= leadfield.mean(axis=0)
leadfield_norm = leadfield / np.linalg.norm(leadfield, axis=0)

n_chans, n_dipoles = leadfield.shape
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   3 out of   8 | elapsed:    2.3s remaining:    3.8s
# [Parallel(n_jobs=8)]: Done   5 out of   8 | elapsed:    2.3s remaining:    1.3s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   3 out of   8 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done   5 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   3 out of   8 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done   5 out of   8 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.1s finished

# %% [markdown]
# # Simulation

# %%
settings = dict(
    number_of_sources=(1, 15), 
    extents=(1, 25), 
    duration_of_trial=0.001, 
    target_snr=1e99, 
    source_number_weighting=True
    )


sim = Simulation(fwd, info, settings).simulate(10000)
stc = sim.source_data[0]
evoked = sim.eeg_data[0].average()

# stc.data /= abs(stc.data).max()
# brain = stc.plot(**pp)
# brain.add_text(0.1, 0.9, 'Ground Truth', 'title',
#                font_size=14)
# evoked.plot_joint()

X, y = prep_data(sim)
# Out:
# -- number of adjacent vertices : 1284
# Simulating data based on sparse patches.
# 100%|██████████| 10000/10000 [01:16<00:00, 129.89it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 23584.57it/s]
# source data shape:  (1284, 1) (1284, 1)
# 100%|██████████| 10000/10000 [00:15<00:00, 652.40it/s]

# %% [markdown]
# # Train

# %% [markdown]
# ## FC Model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, TimeDistributed, Dropout
from tensorflow.keras import backend as K
tf.keras.backend.set_image_data_format('channels_last')

n_channels, n_dipoles = leadfield.shape
n_time = X.shape[1]

n_dense_units = 300
n_lstm_units = 64
activation_function = "tanh"
batch_size = 32
epochs = 50
dropout = 0.2

inputs = tf.keras.Input(shape=(None, n_channels), name='Input')

fc1 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC1'))(inputs)

fc2 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC2'))(fc1)

out = TimeDistributed(Dense(n_dipoles, 
            activation="linear", 
            # activity_regularizer=tf.keras.regularizers.L1(l1=0.001),
            name='Output'))(fc2)

# out = multiply([lstm1, out])

model = tf.keras.Model(inputs=inputs, outputs=out, name='Prelocalizer')
model.compile(loss="cosine_similarity", optimizer="adam")
model.summary()

callbacks = [tf.keras.callbacks.EarlyStopping(patience=4, min_delta=0.00, monitor="val_loss", restore_best_weights=True)]
model.fit(X, y, epochs=epochs, batch_size=batch_size, validation_split=0.15, callbacks=callbacks)
# Out:
# Model: "Prelocalizer"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, None, 128)]       0
#
#  time_distributed_6 (TimeDis  (None, None, 300)        38700
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, None, 300)        90300
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, None, 1284)       386484
#  tributed)
#
# =================================================================
# Total params: 515,484
# Trainable params: 515,484
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 266/266 [==============================] - 3s 9ms/step - loss: -0.1054 - val_loss: -0.1509
# Epoch 2/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.1697 - val_loss: -0.1809
# Epoch 3/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.1947 - val_loss: -0.1987
# Epoch 4/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.2108 - val_loss: -0.2099
# Epoch 5/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.2240 - val_loss: -0.2207
# Epoch 6/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.2348 - val_loss: -0.2286
# Epoch 7/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.2442 - val_loss: -0.2356
# Epoch 8/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.2526 - val_loss: -0.2426
# Epoch 9/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.2604 - val_loss: -0.2493
# Epoch 10/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.2679 - val_loss: -0.2555
# Epoch 11/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.2752 - val_loss: -0.2598
# Epoch 12/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.2819 - val_loss: -0.2644
# Epoch 13/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.2888 - val_loss: -0.2674
# Epoch 14/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.2952 - val_loss: -0.2733
# Epoch 15/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3013 - val_loss: -0.2760
# Epoch 16/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3065 - val_loss: -0.2787
# Epoch 17/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3123 - val_loss: -0.2816
# Epoch 18/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3172 - val_loss: -0.2867
# Epoch 19/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3217 - val_loss: -0.2879
# Epoch 20/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3265 - val_loss: -0.2908
# Epoch 21/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3308 - val_loss: -0.2926
# Epoch 22/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3346 - val_loss: -0.2948
# Epoch 23/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3381 - val_loss: -0.2972
# Epoch 24/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3415 - val_loss: -0.2994
# Epoch 25/50
# 266/266 [==============================] - 2s 9ms/step - loss: -0.3449 - val_loss: -0.3010
# Epoch 26/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3480 - val_loss: -0.3022
# Epoch 27/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3510 - val_loss: -0.3034
# Epoch 28/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3537 - val_loss: -0.3063
# Epoch 29/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3559 - val_loss: -0.3060
# Epoch 30/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3583 - val_loss: -0.3080
# Epoch 31/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3605 - val_loss: -0.3090
# Epoch 32/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3628 - val_loss: -0.3100
# Epoch 33/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3646 - val_loss: -0.3113
# Epoch 34/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3662 - val_loss: -0.3115
# Epoch 35/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3680 - val_loss: -0.3123
# Epoch 36/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3694 - val_loss: -0.3136
# Epoch 37/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3715 - val_loss: -0.3131
# Epoch 38/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3727 - val_loss: -0.3147
# Epoch 39/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3739 - val_loss: -0.3158
# Epoch 40/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3758 - val_loss: -0.3159
# Epoch 41/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3767 - val_loss: -0.3171
# Epoch 42/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3780 - val_loss: -0.3144
# Epoch 43/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3789 - val_loss: -0.3169
# Epoch 44/50
# 266/266 [==============================] - 2s 8ms/step - loss: -0.3803 - val_loss: -0.3171
# Epoch 45/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3815 - val_loss: -0.3189
# Epoch 46/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3824 - val_loss: -0.3190
# Epoch 47/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3835 - val_loss: -0.3205
# Epoch 48/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3843 - val_loss: -0.3189
# Epoch 49/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3853 - val_loss: -0.3196
# Epoch 50/50
# 266/266 [==============================] - 2s 7ms/step - loss: -0.3861 - val_loss: -0.3203

# %% [markdown]
# ## LSTM

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, TimeDistributed, Bidirectional, LSTM, multiply, Dropout, Activation
from tensorflow.keras import backend as K

n_channels, n_dipoles = leadfield.shape
input_shape = (None, None, n_channels)
tf.keras.backend.set_image_data_format('channels_last')

n_dense_units = 300
n_lstm_units = 150
activation_function = "elu"
batch_size = 32
epochs = 40
dropout = 0.2

inputs = tf.keras.Input(shape=(None, n_channels), name='Input')


fc1 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC1'))(inputs)

fc2 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC2'))(fc1)

lstm1 = LSTM(n_lstm_units, return_sequences=True, name='LSTM1')(fc2)

out = TimeDistributed(Dense(n_dipoles, 
            activation="linear", 
            # activity_regularizer=tf.keras.regularizers.L1(l1=0.0001),
            name='Mask'))(lstm1)

model = tf.keras.Model(inputs=inputs, outputs=out, name='Prelocalizer')
model.compile(loss="mse", optimizer="adam")
model.summary()

callbacks = [tf.keras.callbacks.EarlyStopping(patience=10, min_delta=0.00, monitor="val_loss", restore_best_weights=True)]

model.fit(X, y, epochs=epochs, batch_size=batch_size, validation_split=0.15, callbacks=callbacks)
# model.fit(X[:, 0], y_mask, epochs=epochs, batch_size=batch_size, validation_split=0.15)
# Out:
# Model: "Prelocalizer"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, None, 128)]       0
#
#  time_distributed_4 (TimeDis  (None, None, 300)        38700
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, None, 300)        90300
#  tributed)
#
#  LSTM1 (LSTM)                (None, None, 150)         270600
#
#  time_distributed_6 (TimeDis  (None, None, 1284)       193884
#  tributed)
#
# =================================================================
# Total params: 593,484
# Trainable params: 593,484
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 54/54 [==============================] - 4s 14ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 2/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 3/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 4/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 5/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 6/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 7/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 8/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 9/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 10/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 11/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 12/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 13/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 14/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 15/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 16/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 17/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 18/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 19/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 20/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 21/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 22/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 23/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 24/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 25/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 26/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 27/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 28/40
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 29/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 30/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 31/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 32/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 33/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 34/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 35/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 36/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 37/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 38/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 39/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 40/40
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014

# %% [markdown]
# # Eval raw

# %%
# settings = dict(number_of_sources=(1, 15), extents=(1, 25), duration_of_trial=0.001, target_snr=1e99)
settings = dict(number_of_sources=2, extents=25, duration_of_trial=0.01, target_snr=1e99)

sim_test = Simulation(fwd, info, settings).simulate(2)
X_test, y_test = prep_data(sim_test)

y_hat = model.predict(X_test)


# y_hat = model.predict(X_test[:, 0])

plt.figure()
plt.plot(np.linalg.norm(y_hat[0], axis=0))

# plt.figure()
plt.plot(np.linalg.norm(y[0], axis=0))
print(pearsonr(np.linalg.norm(y_hat[0], axis=0), np.linalg.norm(y[0], axis=0)))

stc = sim_test.source_data[0]

stc.data /= abs(stc.data).max()
brain = stc.plot(**pp)
brain.add_text(0.1, 0.9, 'Ground Truth', 'title',
               font_size=14)

stc.data = y_hat[0].T
stc.data /= abs(stc.data).max()
brain = stc.plot(**pp)
brain.add_text(0.1, 0.9, 'Pred', 'title',
               font_size=14)
# Out:
# -- number of adjacent vertices : 1284
# Simulating data based on sparse patches.
# 100%|██████████| 2/2 [00:00<00:00,  3.69it/s]
# 100%|██████████| 2/2 [00:00<00:00, 2005.88it/s]
# source data shape:  (1284, 10) (1284, 10)
# 100%|██████████| 2/2 [00:00<00:00, 286.51it/s]
# 1/1 [==============================] - 0s 71ms/step
# (-0.0016119901181370839, 0.9539827077001574)
# Using control points [0. 0. 1.]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`
# Using control points [0.17132007 0.22174371 0.83193327]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`

# %% [markdown]
# # LSTM Matching Pursuit

# %%
settings = dict(number_of_sources=4, extents=(1, 35), duration_of_trial=0.1, target_snr=1e99)

sim_test = Simulation(fwd, info, settings).simulate(2)
stc = sim_test.source_data[0]
evoked = sim_test.eeg_data[0].average()

stc.data /= abs(stc.data).max()
brain = stc.plot(**pp)
brain.add_text(0.1, 0.9, 'Ground Truth', 'title',
               font_size=14)
evoked.plot_joint()

X_test_norm, y_test_norm = prep_data(sim_test)
# Out:
# -- number of adjacent vertices : 1284
# Simulating data based on sparse patches.
# 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
# 100%|██████████| 2/2 [00:00<00:00, 2002.05it/s]
# source data shape:  (1284, 100) (1284, 100)
# 100%|██████████| 2/2 [00:00<00:00, 47.60it/s]
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...

# %%
from scipy.stats import pearsonr
from invert.util import find_corner, calc_residual_variance
from invert import Solver
max_iter = 25
K = 1
X_test = evoked.data
X_test -= X_test.mean(axis=0)

# dimensions
n_chans, n_dipoles = leadfield.shape
n_time = X_test.shape[-1]

# Predict Gammas
if len(X_test.shape) == 3:
    X_test = X_test[0]

# get initial orthogonal leadfield components
R = deepcopy(X_test)
R -= R.mean(axis=0)
rescale_norms = R.std(axis=0)
R_normed = R / rescale_norms
rescale_norms /= rescale_norms.mean()

y_hat_model = model.predict(R_normed.T[np.newaxis], verbose=0)[0]
y_hat_model = (y_hat_model.T / np.linalg.norm(y_hat_model, axis=1)).T


# solver = Solver("eloreta")
# solver.make_inverse_operator(fwd, alpha=1e-3)
# y_hat_model = solver.apply_inverse_operator(mne.EvokedArray(R, info)).data.T
# y_hat_model = (y_hat_model.T / np.linalg.norm(y_hat_model, axis=1)).T

gammas_model = np.mean(abs(y_hat_model), axis=0)
gammas_model /= gammas_model.max()

# stc_ = stc.copy()
# stc_.data = y_hat_model.T
# stc_.plot(**pp, brain_kwargs=dict(title="Model Predictions"))

residual_norms = [1e99,]
idc = np.array([])
for i in range(max_iter):
    stc_ = stc.copy()

    # y_hat_model = model.predict(R_normed.T[np.newaxis], verbose=0)[0]
    # y_hat_model = (y_hat_model.T / np.linalg.norm(y_hat_model, axis=1)).T
    # gammas_model = np.mean(abs(y_hat_model), axis=0)
    # gammas_model /= gammas_model.max()

    # y_hat_model = solver.apply_inverse_operator(mne.EvokedArray(R, info)).data.T
    # gammas_model = np.mean(abs(y_hat_model), axis=0)
    # gammas_model /= gammas_model.max()
    
    mp = (leadfield_norm.T @ R )
    mp *= rescale_norms
    gammas_mp = np.linalg.norm(mp, axis=1, ord=1)
    gammas_mp /= gammas_mp.max()
    
    gammas = gammas_model * gammas_mp
    # gammas = gammas_mp

    stc_.data[:,0] = gammas_model
    stc_.data[:,1] = gammas_mp
    stc_.data[:,2] = gammas
    # stc_.plot(**pp, brain_kwargs=dict(title=f'{i} Gammas'))

    idx = np.argsort(gammas)[-K:]

    # arg_sorted = np.argsort(gammas)[::-1]
    # ii = 0
    # idx = arg_sorted[ii]
    # while idx in idc:
    #     print("idx reselected")
    #     ii += 1
    #     idx = arg_sorted[ii]

    idc = np.unique(np.append(idc, idx)).astype(int)

    # Remove IDC that dont really explain variance in the whole data
    # Inversion
    # corrs = np.mean(abs((leadfield_norm.T @ X_test)), axis=1)[idc]
    # highest_K = corrs > corrs.max()/2#np.argsort(corrs)[-K:]
    # idc = idc[highest_K]

    print(idc)

    # Inversion
    leadfield_pinv = np.linalg.pinv(leadfield[:, idc])
    y_hat = np.zeros((n_dipoles, n_time))
    y_hat[idc] = leadfield_pinv @ X_test

    X_hat = leadfield @ y_hat
    # Rereference predicted EEG
    X_hat -= X_hat.mean(axis=0)
    
    # Calculate Residual
    R = X_test - X_hat
    R -= R.mean(axis=0)

    # Rereference and scale predicted Residual
    
    
    residual_norm = np.linalg.norm(R)
    residual_norms.append( residual_norm )
    
    rescale_norms = R.std(axis=0)

    R_normed = R / rescale_norms
    rescale_norms /= rescale_norms.mean()

    # print(idc)
    # print(residual_norm)
    rv = calc_residual_variance(X_hat, X_test)
    print(i, " Res var: ", rv)
    # break


    # evoked_true = mne.EvokedArray(X_test, info, verbose=0)
    # evoked_hat = mne.EvokedArray(X_hat, info, verbose=0)
    # evoked_res = mne.EvokedArray(R, info, verbose=0)
    # evoked_true.plot_joint(title="True")
    # evoked_hat.plot_joint(title="Current X_hat")
    # evoked_res.plot_joint(title="Residual")

    # stc_.data = y_hat
    # stc_.plot(**pp, brain_kwargs=dict(title=f"Prediction {i}"))
    # if residual_norms[-1] >= residual_norms[-2] or rv<1:
    if rv<0.1:
    
        break
    
X_hat = leadfield@y_hat

# evoked_ = mne.EvokedArray(X_hat, info)
# evoked_.plot_joint()
# Out:
# [1096]
# 0  Res var:  35.8700060798393
# [ 955 1096]
# 1  Res var:  20.398090854657983
# [ 943  955 1096]
# 2  Res var:  7.7389100698601405
# [ 784  943  955 1096]
# 3  Res var:  5.999876751540561
# [  47  784  943  955 1096]
# 4  Res var:  2.937128038347829
# [  47  102  784  943  955 1096]
# 5  Res var:  1.166580709194164
# [  47  102  784  943  955 1095 1096]
# 6  Res var:  0.3735481369741824
# [  47  102  479  784  943  955 1095 1096]
# 7  Res var:  0.20987353087337374
# [  47  102  479  735  784  943  955 1095 1096]
# 8  Res var:  0.11534712276469193
# [  47  102  479  735  784  943  955 1095 1096 1227]
# 9  Res var:  0.07908677871366428

# %%
stc_ = stc.copy()
stc_.data = y_hat / abs(y_hat).max()
brain = stc_.plot(**pp)
brain.add_text(0.1, 0.9, 'Pred', 'title',
               font_size=14)

x_hat = leadfield@y_hat

evoked_ = mne.EvokedArray(x_hat, info)
evoked_.plot_joint()
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.

# %% [markdown]
# # Champagne for scale

# %%
solver = Solver("champagne")
solver.make_inverse_operator(fwd, alpha=1e-3)
stc_champ = solver.apply_inverse_operator(mne.EvokedArray(X_test, info))
stc_champ.plot(**pp, brain_kwargs=dict(title="Champ"))

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib qt
import sys; sys.path.insert(0, '../')
from copy import deepcopy
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import pearsonr
import mne
from esinet import Simulation
from esinet.forward import get_info, create_forward_model
from esinet.util import unpack_fwd
pp = dict(surface='white', hemi='both')

# %% [markdown]
# # Funs

# %%
def prep_data(sim):
    X = np.stack([eeg.average().data for eeg in sim.eeg_data])
    y = np.stack([src.data for src in sim.source_data])
    for i, (x_sample, y_sample) in enumerate(zip(X, y)):
        # X[i] = np.stack([(x - np.mean(x)) / np.std(x) for x in x_sample.T], axis=0).T
        # y[i] = np.stack([ y / np.max(abs(y)) for y in y_sample.T], axis=0).T

        X[i] = np.stack([x - np.mean(x) for x in x_sample.T], axis=0).T
        X[i] = np.stack([x / np.std(x) for x in x_sample.T], axis=0).T
        
        # X[i] /= np.linalg.norm(X[i])
        y[i] /= np.max(abs(y[i]))

    X = np.swapaxes(X, 1,2)
    y = np.swapaxes(y, 1,2)
    
    return X, y
    
def make_mask(y, thresh=0.001):
    y_mask = np.zeros((y.shape[0], y.shape[-1]))
    for i, y_samp in enumerate(y):
        yy = abs(y_samp).mean(axis=0)
        

        y_mask[i] = (yy > yy.max()*thresh).astype(int)
    return y_mask

def get_components(X, leadfield_norm):
    for i, x_sample in enumerate(X):
        X[i] = np.stack([x - np.mean(x) for x in x_sample.T], axis=0).T
        X[i] /= np.linalg.norm(X[i])

    X_components = np.stack([leadfield_norm.T @ X_sample.T for X_sample in X], axis=0)
    X_components = np.swapaxes(X_components, 1, 2)
    X_components = np.stack([XX / np.linalg.norm(XX) for XX in X_components], axis=0)
    return np.abs(X_components)

# %% [markdown]
# # Forward

# %%
info = get_info(kind='biosemi128')
fwd = create_forward_model(info=info, sampling='ico3')

leadfield, pos = unpack_fwd(fwd)[1:3]
leadfield -= leadfield.mean(axis=0)
leadfield_norm = leadfield / np.linalg.norm(leadfield, axis=0)

n_chans, n_dipoles = leadfield.shape
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    2.5s remaining:    2.5s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.4s finished

# %% [markdown]
# # Simulation

# %%
# settings = dict(number_of_sources=(1, 15), extents=(1, 25), duration_of_trial=0.001, target_snr=1e99)
settings = dict(number_of_sources=(1, 15), extents=(1, 25), duration_of_trial=0.01, target_snr=1e99, source_number_weighting=False)


sim = Simulation(fwd, info, settings).simulate(2000)
stc = sim.source_data[0]
evoked = sim.eeg_data[0].average()

# stc.data /= abs(stc.data).max()
# brain = stc.plot(**pp)
# brain.add_text(0.1, 0.9, 'Ground Truth', 'title',
#                font_size=14)
# evoked.plot_joint()

X, y = prep_data(sim)
# Out:
# -- number of adjacent vertices : 1284
# Simulating data based on sparse patches.
# 100%|██████████| 2000/2000 [00:12<00:00, 160.99it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 15977.75it/s]
# source data shape:  (1284, 10) (1284, 10)
# 100%|██████████| 2000/2000 [00:06<00:00, 293.22it/s]

# %% [markdown]
# # Train

# %% [markdown]
# ## FC Model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, TimeDistributed, Bidirectional, LSTM, multiply, Dropout
from tensorflow.keras import backend as K
tf.keras.backend.set_image_data_format('channels_last')

n_channels, n_dipoles = leadfield.shape
n_time = X.shape[1]

n_dense_units = 300
n_lstm_units = 64
activation_function = "elu"
batch_size = 32
epochs = 50
dropout = 0.2

inputs = tf.keras.Input(shape=(None, n_channels), name='Input')

fc1 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC1'))(inputs)

fc2 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC2'))(fc1)

fc3 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC3'))(fc2)


# Masking
# lstm1 = Bidirectional(LSTM(n_lstm_units, return_sequences=False, 
#             input_shape=(None, n_dense_units)), 
#             name='LSTM1')(fc3)
# lstm1 = Dense(n_dipoles, 
#             activation="sigmoid", 
#             name='Mask')(lstm1)

out = TimeDistributed(Dense(n_dipoles, 
            activation="linear", 
            # activity_regularizer=tf.keras.regularizers.L1(l1=0.001),
            name='Output'))(fc3)

# out = multiply([lstm1, out])

model = tf.keras.Model(inputs=inputs, outputs=out, name='Prelocalizer')
model.compile(loss="mse", optimizer="adam")
model.summary()

callbacks = [tf.keras.callbacks.EarlyStopping(patience=4, min_delta=0.00, monitor="val_loss", restore_best_weights=True)]
model.fit(X, y, epochs=epochs, batch_size=batch_size, validation_split=0.15, callbacks=callbacks)
# Out:
# Model: "Prelocalizer"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, None, 128)]       0
#
#  time_distributed_24 (TimeDi  (None, None, 300)        38700
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, None, 300)        90300
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, None, 300)        90300
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, None, 1284)       386484
#  stributed)
#
# =================================================================
# Total params: 605,784
# Trainable params: 605,784
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0076 - val_loss: 0.0023
# Epoch 2/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 3/50
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 4/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 5/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 6/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 7/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 8/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 9/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 10/50
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 11/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 12/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 13/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 14/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 15/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 16/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 17/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 18/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 19/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 20/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 21/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 22/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 23/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 24/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 25/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 26/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 27/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 28/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 29/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 30/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 31/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 32/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 33/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 34/50
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 35/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 36/50
# 54/54 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 37/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 38/50
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 39/50
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0014

# %% [markdown]
# ## LSTM

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, TimeDistributed, Bidirectional, LSTM, multiply, Dropout, Activation
from tensorflow.keras import backend as K

n_channels, n_dipoles = leadfield.shape
input_shape = (None, None, n_channels)
tf.keras.backend.set_image_data_format('channels_last')

n_dense_units = 300
n_lstm_units = 150
activation_function = "elu"
batch_size = 32
epochs = 40
dropout = 0.2

inputs = tf.keras.Input(shape=(None, n_channels), name='Input')


fc1 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC1'))(inputs)

fc2 = TimeDistributed(Dense(n_dense_units, 
            activation=activation_function,
            name='FC2'))(fc1)

lstm1 = LSTM(n_lstm_units, return_sequences=True, name='LSTM1')(fc2)

out = TimeDistributed(Dense(n_dipoles, 
            activation="linear", 
            # activity_regularizer=tf.keras.regularizers.L1(l1=0.0001),
            name='Mask'))(lstm1)

model = tf.keras.Model(inputs=inputs, outputs=out, name='Prelocalizer')
model.compile(loss="mse", optimizer="adam")
model.summary()

callbacks = [tf.keras.callbacks.EarlyStopping(patience=10, min_delta=0.00, monitor="val_loss", restore_best_weights=True)]

model.fit(X, y, epochs=epochs, batch_size=batch_size, validation_split=0.15, callbacks=callbacks)
# model.fit(X[:, 0], y_mask, epochs=epochs, batch_size=batch_size, validation_split=0.15)
# Out:
# Model: "Prelocalizer"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, None, 128)]       0
#
#  time_distributed_5 (TimeDis  (None, None, 300)        38700
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, None, 300)        90300
#  tributed)
#
#  LSTM1 (LSTM)                (None, None, 150)         270600
#
#  time_distributed_7 (TimeDis  (None, None, 1284)       193884
#  tributed)
#
# =================================================================
# Total params: 593,484
# Trainable params: 593,484
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 54/54 [==============================] - 3s 20ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 2/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 3/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 4/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 5/40
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 6/40
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 7/40
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 8/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 9/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 10/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 11/40
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 12/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 13/40
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 14/40
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 15/40
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 16/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 17/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 18/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 19/40
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 20/40
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 21/40
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 22/40
# 54/54 [==============================] - 1s 12ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 23/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 24/40
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 25/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 26/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 27/40
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 28/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 29/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 30/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 31/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 32/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 33/40
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 34/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 35/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 36/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 37/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 38/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 39/40
# 54/54 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 40/40
# 54/54 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 0.0013

# %% [markdown]
# # Eval raw

# %%
# settings = dict(number_of_sources=(1, 15), extents=(1, 25), duration_of_trial=0.001, target_snr=1e99)
settings = dict(number_of_sources=2, extents=25, duration_of_trial=0.01, target_snr=1e99)

sim_test = Simulation(fwd, info, settings).simulate(2)
X_test, y_test = prep_data(sim_test)

y_hat = model.predict(X_test)


# y_hat = model.predict(X_test[:, 0])

plt.figure()
plt.plot(np.linalg.norm(y_hat[0], axis=0))

# plt.figure()
plt.plot(np.linalg.norm(y[0], axis=0))
print(pearsonr(np.linalg.norm(y_hat[0], axis=0), np.linalg.norm(y[0], axis=0)))

stc = sim_test.source_data[0]

stc.data /= abs(stc.data).max()
brain = stc.plot(**pp)
brain.add_text(0.1, 0.9, 'Ground Truth', 'title',
               font_size=14)

stc.data = y_hat[0].T
stc.data /= abs(stc.data).max()
brain = stc.plot(**pp)
brain.add_text(0.1, 0.9, 'Pred', 'title',
               font_size=14)
# Out:
# -- number of adjacent vertices : 1284
# Simulating data based on sparse patches.
# 100%|██████████| 2/2 [00:00<00:00,  3.69it/s]
# 100%|██████████| 2/2 [00:00<00:00, 2005.88it/s]
# source data shape:  (1284, 10) (1284, 10)
# 100%|██████████| 2/2 [00:00<00:00, 286.51it/s]
# 1/1 [==============================] - 0s 71ms/step
# (-0.0016119901181370839, 0.9539827077001574)
# Using control points [0. 0. 1.]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`
# Using control points [0.17132007 0.22174371 0.83193327]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`

# %% [markdown]
# # LSTM Matching Pursuit

# %%
settings = dict(number_of_sources=4, extents=(1, 20), duration_of_trial=0.01, target_snr=1e99)

sim_test = Simulation(fwd, info, settings).simulate(2)
stc = sim_test.source_data[0]
evoked = sim_test.eeg_data[0].average()

stc.data /= abs(stc.data).max()
brain = stc.plot(**pp)
brain.add_text(0.1, 0.9, 'Ground Truth', 'title',
               font_size=14)
evoked.plot_joint()

X_test_norm, y_test_norm = prep_data(sim_test)
# Out:
# -- number of adjacent vertices : 1284
# Simulating data based on sparse patches.
# 100%|██████████| 2/2 [00:00<00:00,  3.24it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# source data shape:  (1284, 10) (1284, 10)
# 100%|██████████| 2/2 [00:00<00:00, 182.31it/s]
# Using control points [0.         0.         0.90698442]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...

# %%
from scipy.stats import pearsonr
from invert.util import find_corner, calc_residual_variance
max_iter = 50
K = 1
X_test = evoked.data
X_test -= X_test.mean(axis=0)

# dimensions
n_chans, n_dipoles = leadfield.shape
n_time = X_test.shape[-1]

# Predict Gammas
if len(X_test.shape) == 3:
    X_test = X_test[0]

# get initial orthogonal leadfield components
R = deepcopy(X_test_norm[0].T)
rescale_norms = X_test.std(axis=0)
# rescale_norms = np.ones(10)

residual_norms = [1e99,]
idc = np.array([])
for i in range(max_iter):
    y_hat_model = model.predict(R.T[np.newaxis], verbose=0)[0]
    
    
    y_hat_model = np.stack([n * y_hat_model[i] for i, n in enumerate(rescale_norms)], axis=0)
    gammas = np.linalg.norm(y_hat_model, axis=0)
    gammas /= gammas.max()

    # stc_ = stc.copy()
    # stc_.data[:,0] = gammas
    # stc_.plot(**pp)

    gammas_mp = np.linalg.norm(leadfield_norm.T @ R / np.linalg.norm(R), axis=1)
    # gammas_mp /= gammas_mp.max()


    
    gammas = gammas * gammas_mp

    # gammas = gammas_mp

    # plt.figure()
    # plt.plot(gammas)


    # plt.figure()
    # plt.subplot(211)
    # plt.plot(gammas)
    # plt.title("Gamma")

    
    # plt.subplot(212)
    # plt.plot(gammas)
    # plt.title("Gamma*comp")

    idx = np.argsort(gammas)[-K:]

    arg_sorted = np.argsort(gammas)[::-1]
    ii = 0
    idx = arg_sorted[ii]
    while idx in idc:
        ii += 1
        idx = arg_sorted[ii]

    idc = np.unique(np.append(idc, idx)).astype(int)
    print(idc)

    # Inversion Scheme 1
    leadfield_pinv = np.linalg.pinv(leadfield[:, idc])
    y_hat = np.zeros((n_dipoles, n_time))
    y_hat[idc] = leadfield_pinv @ X_test
    
    # Inversion Scheme 2
    # gammas = np.zeros(n_dipoles)
    # gammas[idc] = 1
    # y_hat = np.diag(gammas) @ leadfield.T @ X_test

    X_hat = leadfield @ y_hat
    # Rereference predicted EEG
    X_hat -= X_hat.mean(axis=0)
    
    # Calculate Residual
    # R = X_test - X_hat
    R = X_test / X_test.std(axis=0) - X_hat / X_hat.std(axis=0)
    
    # Rereference and scale predicted Residual
    R -= R.mean(axis=0)

    
    residual_norm = np.linalg.norm(R)
    residual_norms.append( residual_norm )
    
    rescale_norms = R.std(axis=0)
    # rescale_norms = np.ones(10)

    R /= rescale_norms

    # print(idc)
    print(residual_norm)
    rv = calc_residual_variance(X_hat, X_test)
    print("Res var: ", rv)
    # break

    # plt.figure()
    # plt.subplot(311)
    # # im, _ = mne.viz.plot_topomap(np.linalg.norm(X_test, axis=1), info)
    # im, _ = mne.viz.plot_topomap(X_test_norm[0, 0, :], info)
    # plt.colorbar(im)
    # plt.title("True")
    # plt.subplot(312)
    # # im, _ = mne.viz.plot_topomap(np.linalg.norm(X_hat, axis=1), info)
    # im, _ = mne.viz.plot_topomap(X_hat[:, 0], info)
    
    # plt.colorbar(im)
    # plt.title("Current X_hat")
    # plt.subplot(313)
    # # im, _ = mne.viz.plot_topomap(np.linalg.norm(R, axis=1), info)
    # im, _ = mne.viz.plot_topomap(R[:, 0], info)
    # plt.colorbar(im)
    # plt.title("Residual")

    # if residual_norms[-1] >= residual_norms[-2] or rv<1:
    if rv<1:
    
        break
    
X_hat = leadfield@y_hat

evoked_ = mne.EvokedArray(X_hat, info)
evoked_.plot_joint()
# Out:
# [1086]
# 21.307638549257312
# Res var:  29.765935553574327
# [ 729 1086]
# 19.929388065006545
# Res var:  26.936667731527915
# [ 729 1085 1086]
# 17.434356875370376
# Res var:  19.229290507495175
# [ 729 1085 1086 1087]
# 16.85660175264302
# Res var:  18.074784346135658
# [ 729  991 1085 1086 1087]
# 15.580169877677243
# Res var:  15.0098716613038
# [ 729  991 1085 1086 1087 1268]
# 15.366153257076666
# Res var:  14.808216065132425
# [ 729  800  991 1085 1086 1087 1268]
# 10.214899111146863
# Res var:  5.00214394648058
# [ 729  800  991 1003 1085 1086 1087 1268]
# 10.048705936487295
# Res var:  4.951896158882296
# [ 729  800  991 1003 1085 1086 1087 1258 1268]
# 9.977512979308436
# Res var:  4.836444394685523
# [ 729  800  991  994 1003 1085 1086 1087 1258 1268]
# 7.656828457214693
# Res var:  2.57245406816665
# [ 729  800  962  991  994 1003 1085 1086 1087 1258 1268]
# 6.4109881518462455
# Res var:  1.6147946170284437
# [ 184  729  800  962  991  994 1003 1085 1086 1087 1258 1268]
# 4.529586281763452
# Res var:  1.0008633016649302
# [ 184  377  729  800  962  991  994 1003 1085 1086 1087 1258 1268]
# 3.4273288710966012
# Res var:  0.6453405194856404
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
stc_ = stc.copy()
stc_.data = y_hat / abs(y_hat).max()
brain = stc_.plot(**pp)
brain.add_text(0.1, 0.9, 'Pred', 'title',
               font_size=14)

x_hat = leadfield@y_hat

evoked_ = mne.EvokedArray(x_hat, info)
evoked_.plot_joint()
# Out:
# Using control points [0.         0.         0.51605503]
# For automatic theme detection, "darkdetect" has to be installed! You can install it with `pip install darkdetect`
# To use light mode, "qdarkstyle" has to be installed! You can install it with `pip install qdarkstyle`
# No projector specified for this dataset. Please consider the method self.add_proj.
# Using control points [0.         0.         0.10846622]
